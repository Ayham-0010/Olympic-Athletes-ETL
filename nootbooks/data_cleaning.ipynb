# %%
import pandas as pd
import numpy as np
import pandera.pandas as pa 

import re
import ast

# %%
# Load your data
bios_df = pd.read_csv("../clean_data/cleaned_biodata.csv")
results_df = pd.read_csv('../clean_data/cleaned_results.csv')

affiliation_df = pd.read_csv("../clean_data/dim_affiliation.csv")

# %%
bios_df
# Out:
#                                                  Roles     Sex  \
# 0                        ['Competed in Olympic Games']    Male
# 1                        ['Competed in Olympic Games']    Male
# 2       ['Competed in Olympic Games', 'Administrator']    Male
# 3                        ['Competed in Olympic Games']    Male
# 4                        ['Competed in Olympic Games']    Male
# ...                                                ...     ...
# 145560                   ['Competed in Olympic Games']    Male
# 145561                   ['Competed in Olympic Games']    Male
# 145562                   ['Competed in Olympic Games']    Male
# 145563                   ['Competed in Olympic Games']  Female
# 145564                ['Non-starter', 'Administrator']    Male
#
#                           NOC  Athlete_Id                   Name  Height (cm)  \
# 0                  ['france']           2         Arnaud Boetsch        183.0
# 1                  ['france']           1  Jean-François Blanchy          NaN
# 2                  ['france']           3           Jean Borotra        183.0
# 3                  ['france']           5           Albert Canet          NaN
# 4                  ['france']           4        Jacques Brugnon        168.0
# ...                       ...         ...                    ...          ...
# 145560  ['republic of korea']      149217            Sin Ye-Chan          NaN
# 145561               ['cuba']      149219  Carlos García-Ordóñez          NaN
# 145562             ['france']      149225         André Foussard        166.0
# 145563                ['roc']      149223    Valeriya Merkusheva        168.0
# 145564          ['australia']      149814          Bill Phillips          NaN
#
#         Weight (kg)   Born_Date   Died_Date  Is_Alive           Born_City  \
# 0              76.0  1969-04-01         NaN      True              Meulan
# 1               NaN  1886-12-12  1960-10-02     False            Bordeaux
# 2              76.0  1898-08-13  1994-07-17     False            Biarritz
# 3               NaN  1878-04-17  1930-07-25     False          Wandsworth
# 4              64.0  1895-05-11  1978-03-20     False         Paris VIIIe
# ...             ...         ...         ...       ...                 ...
# 145560          NaN  1995-06-13         NaN      True                 NaN
# 145561          NaN  1927-04-24  2019-11-24     False  La Habana (Havana)
# 145562          NaN  1899-05-19  1986-03-18     False               Niort
# 145563         65.0  1999-09-20         NaN      True     Moskva (Moscow)
# 145564          NaN  1913-07-15  2003-10-20     False        Dulwich Hill
#
#                   Born_Region Born_Country
# 0                   Yvelines           FRA
# 1                    Gironde           FRA
# 2       Pyrénées-Atlantiques           FRA
# 3                    England           GBR
# 4                      Paris           FRA
# ...                       ...          ...
# 145560                    NaN          NaN
# 145561   Ciudad de La Habana           CUB
# 145562           Deux-Sèvres           FRA
# 145563                Moskva           RUS
# 145564       New South Wales           AUS
#
# [145565 rows x 13 columns]

# %%
bios_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145565 entries, 0 to 145564
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Roles         145565 non-null  object
#  1   Sex           145565 non-null  object
#  2   NOC           145565 non-null  object
#  3   Athlete_Id    145565 non-null  int64
#  4   Name          145565 non-null  object
#  5   Height (cm)   106716 non-null  float64
#  6   Weight (kg)   102128 non-null  float64
#  7   Born_Date     143763 non-null  object
#  8   Died_Date     33965 non-null   object
#  9   Is_Alive      145565 non-null  bool
#  10  Born_City     112574 non-null  object
#  11  Born_Region   112574 non-null  object
#  12  Born_Country  112574 non-null  object
# dtypes: bool(1), float64(2), int64(1), object(9)
# memory usage: 13.5+ MB

# %%
bios_df.describe(include='all')
# Out:
#                                 Roles     Sex                NOC  \
# count                          145565  145565             145565
# unique                             69       2                490
# top     ['Competed in Olympic Games']    Male  ['united states']
# freq                           134667  106361              10117
# mean                              NaN     NaN                NaN
# std                               NaN     NaN                NaN
# min                               NaN     NaN                NaN
# 25%                               NaN     NaN                NaN
# 50%                               NaN     NaN                NaN
# 75%                               NaN     NaN                NaN
# max                               NaN     NaN                NaN
#
#            Athlete_Id         Name    Height (cm)    Weight (kg)   Born_Date  \
# count   145565.000000       145565  106716.000000  102128.000000      143763
# unique            NaN       142845            NaN            NaN       41281
# top               NaN  Ivan Ivanov            NaN            NaN  1931-01-01
# freq              NaN           13            NaN            NaN          63
# mean     73706.774863          NaN     176.333746      71.889707         NaN
# std      42870.703583          NaN      10.382117      14.466176         NaN
# min          1.000000          NaN     127.000000      25.000000         NaN
# 25%      36680.000000          NaN     170.000000      62.000000         NaN
# 50%      73335.000000          NaN     176.000000      70.000000         NaN
# 75%     110354.000000          NaN     183.000000      80.000000         NaN
# max     149814.000000          NaN     226.000000     198.000000         NaN
#
#          Died_Date Is_Alive Born_City Born_Region Born_Country
# count        33965   145565    112574      112574       112574
# unique       20009        2     24126        2436          224
# top     2002-01-01     True         ?    England           USA
# freq            47   111600      2347        5012        10005
# mean           NaN      NaN       NaN         NaN          NaN
# std            NaN      NaN       NaN         NaN          NaN
# min            NaN      NaN       NaN         NaN          NaN
# 25%            NaN      NaN       NaN         NaN          NaN
# 50%            NaN      NaN       NaN         NaN          NaN
# 75%            NaN      NaN       NaN         NaN          NaN
# max            NaN      NaN       NaN         NaN          NaN

# %%
def df_nan_percentage(df):
    return df.isna().mean().mul(100).round(2).sort_values(ascending=False).map(lambda x: f"{x}%")
df_nan_percentage(bios_df)
# Out:
# Died_Date       76.67%
# Weight (kg)     29.84%
# Height (cm)     26.69%
# Born_City       22.66%
# Born_Country    22.66%
# Born_Region     22.66%
# Born_Date        1.24%
# Name              0.0%
# Sex               0.0%
# Roles             0.0%
# Athlete_Id        0.0%
# NOC               0.0%
# Is_Alive          0.0%
# dtype: object

# %%
# Count how many disciplines per athlete
discipline_counts = results_df.groupby('Athlete_Id')['Discipline'].nunique()

# See if any have more than 1
multi_discipline = discipline_counts[discipline_counts > 1]

print(f"Number of athletes with multiple disciplines: {len(multi_discipline)}")
print(f"Total athletes in results: {len(discipline_counts)}")
print(f"Percentage: {len(multi_discipline) / len(discipline_counts) * 100:.2f}%")
# Out:
# Number of athletes with multiple disciplines: 1032
# Total athletes in results: 145561
# Percentage: 0.71%

# %%
print("Duplicate Athlete_Id in bio_df:", bios_df['Athlete_Id'].duplicated().sum())
print("Total rows in bio_df:", len(bios_df))
print("Unique Athlete_Id:", bios_df['Athlete_Id'].nunique())
# Out:
# Duplicate Athlete_Id in bio_df: 0
# Total rows in bio_df: 145565
# Unique Athlete_Id: 145565

# %%
def impute_height_weight_by_discipline(bio_df, results_df):
    """
    Impute Height (cm) and Weight (kg) using the median of
    Sex + Discipline (primary) and Sex only (fallback).

    Parameters
    ----------
    bio_df      : DataFrame with columns ['Athlete_Id', 'Sex', 'Height (cm)', 'Weight (kg)', ...]
    results_df  : DataFrame with columns ['Athlete_Id', 'Discipline', ...]

    Returns
    -------
    bio_imputed : DataFrame (same shape as bio_df) with imputed values and two flag columns
    """
    bio = bio_df.copy()

    # -------------------------------------------------
    # 1. ONE DISCIPLINE PER ATHLETE (most frequent)
    # -------------------------------------------------
    discipline_map = (
        results_df.groupby('Athlete_Id')['Discipline']
        .apply(lambda s: s.mode().iloc[0] if not s.mode().empty else np.nan)
        .reset_index()
    )
    bio = bio.merge(discipline_map, on='Athlete_Id', how='left')

    # -------------------------------------------------
    # 2. IMPUTATION FLAGS (before any filling)
    # -------------------------------------------------
    bio['Height_Imputed'] = bio['Height (cm)'].isna()
    bio['Weight_Imputed'] = bio['Weight (kg)'].isna()

    # -------------------------------------------------
    # 3. MEDIANS BY Sex + Discipline
    # -------------------------------------------------
    grp = bio.groupby(['Sex', 'Discipline'])
    height_med_sex_disc = grp['Height (cm)'].transform('median')
    weight_med_sex_disc = grp['Weight (kg)'].transform('median')

    # Fill with Sex+Discipline median where possible
    bio['Height (cm)'] = bio['Height (cm)'].fillna(height_med_sex_disc)
    bio['Weight (kg)'] = bio['Weight (kg)'].fillna(weight_med_sex_disc)

    # -------------------------------------------------
    # 4. FALLBACK: MEDIAN BY Sex ONLY
    # -------------------------------------------------
    bio['Height (cm)'] = bio.groupby('Sex')['Height (cm)'].transform(
        lambda x: x.fillna(x.median())
    )
    bio['Weight (kg)'] = bio.groupby('Sex')['Weight (kg)'].transform(
        lambda x: x.fillna(x.median())
    )

    # -------------------------------------------------
    # 5. UPDATE FLAGS FOR FALLBACK IMPUTATIONS
    # -------------------------------------------------
    # Original missing values that are now filled
    orig_height_na = bio_df['Height (cm)'].isna()
    orig_weight_na = bio_df['Weight (kg)'].isna()

    bio['Height_Imputed'] = bio['Height_Imputed'] | (orig_height_na & bio['Height (cm)'].notna())
    bio['Weight_Imputed'] = bio['Weight_Imputed'] | (orig_weight_na & bio['Weight (kg)'].notna())

    # -------------------------------------------------
    # 6. CLEAN-UP
    # -------------------------------------------------
    bio = bio.drop(columns=['Discipline'])

    return bio

# %%
# Impute!
bios_df = impute_height_weight_by_discipline(bios_df, results_df)

# %%
bios_df.isna().mean().mul(100).round(2).sort_values(ascending=False).map(lambda x: f"{x}%")
# Out:
# Died_Date         76.67%
# Born_City         22.66%
# Born_Country      22.66%
# Born_Region       22.66%
# Born_Date          1.24%
# Sex                 0.0%
# Roles               0.0%
# Weight (kg)         0.0%
# Height (cm)         0.0%
# Name                0.0%
# Athlete_Id          0.0%
# NOC                 0.0%
# Is_Alive            0.0%
# Height_Imputed      0.0%
# Weight_Imputed      0.0%
# dtype: object

# %%
def impute_Born_Country_by_NOC(bios_df):
    # clean_bio_df = pd.read_csv('your_bio_df.csv')  # assuming it's already loaded
    bios_df = bios_df.copy()
    # Load the ISO country codes CSV
    iso_df = pd.read_csv('../data/wikipedia-iso-country-codes.csv')

    # Create a mapping from lowercase English short name to Alpha-3 code
    country_to_code = dict(zip(iso_df['English short name lower case'].str.lower(), iso_df['Alpha-3 code']))

    # Function to get the first NOC country code
    def get_noc_code(noc_list):
        noc_list = ast.literal_eval(noc_list)
        if len(noc_list) > 0:
            return country_to_code.get(noc_list[0])
        return np.nan

    # Create a flag column to indicate when Born_Country is derived from NOC
    bios_df['Born_Country_From_NOC'] = False

    # Apply the function only where Born_Country is missing
    mask = bios_df['Born_Country'].isna()
    bios_df.loc[mask, 'Born_Country'] = bios_df.loc[mask, 'NOC'].apply(get_noc_code)
    bios_df.loc[mask, 'Born_Country_From_NOC'] = True
    
    return bios_df

# %%
bios_df = impute_Born_Country_by_NOC(bios_df)

# %% [markdown]
# country_to_code = dict(zip(iso_df['English short name lower case'].str.lower(), iso_df['Alpha-3 code']))
# country_to_code.get('france')

# %%
count_none = len(bios_df[(bios_df['Born_Country_From_NOC']==True) & (bios_df['Born_Country'].isna())])
count_not_none = len(bios_df[(bios_df['Born_Country_From_NOC']==True) & (bios_df['Born_Country'].notna())])

print(f"Count of None in Born_Country where derived from NOC: {count_none}")
print(f"Count of Not None in Born_Country where derived from NOC: {count_not_none}")
# Out:
# Count of None in Born_Country where derived from NOC: 6630
# Count of Not None in Born_Country where derived from NOC: 26361

# %%
bios_df.isna().mean().mul(100).round(2).sort_values(ascending=False).map(lambda x: f"{x}%")
# Out:
# Died_Date                76.67%
# Born_City                22.66%
# Born_Region              22.66%
# Born_Country              4.55%
# Born_Date                 1.24%
# Roles                      0.0%
# NOC                        0.0%
# Sex                        0.0%
# Weight (kg)                0.0%
# Height (cm)                0.0%
# Name                       0.0%
# Athlete_Id                 0.0%
# Is_Alive                   0.0%
# Height_Imputed             0.0%
# Weight_Imputed             0.0%
# Born_Country_From_NOC      0.0%
# dtype: object

# %%
# bios_df[bios_df['Athlete_Id'].isin([1812, 3997, 6237, 6292, 6317, 6468, 6679, 6759, 6775, 6863, 7015, 7158, 7250, 7673, 8270, 8928, 11272, 11572, 11706, 11779, 12191, 13017, 15259, 17449, 17613, 17635, 19553, 19621, 19626, 20180, 21166, 21750, 22025, 22362, 22368, 23530, 23541, 24096, 24429, 24722, 24749, 24755, 24779, 24787, 24790, 24809, 24817, 25804, 26222, 28041, 30715, 31008, 31912, 38083, 39441, 39442, 39444, 39452, 39457, 39798, 39814, 40973, 40972, 41015, 41298, 42210, 42240, 42660, 46418, 47918, 47978, 50179, 53725, 54682, 54710, 55563, 58663, 58795, 58818, 58907, 60619, 61190, 68201, 72894, 79628, 79765, 79824, 79881, 79900, 79957, 128839])]
bios_df[bios_df['Name'].isin(['Ahmed Salem', 'Nikolaos Kaloudis', 'Georges Dubois'])]
# Out:
#                                Roles   Sex              NOC  Athlete_Id  \
# 16309  ['Competed in Olympic Games']  Male        ['egypt']       16427
# 24613  ['Competed in Olympic Games']  Male        ['egypt']       24803
# 25396  ['Competed in Olympic Games']  Male       ['greece']       25584
# 53599  ['Competed in Olympic Games']  Male       ['greece']       54085
# 67689  ['Competed in Olympic Games']  Male       ['france']       68201
# 79675  ['Competed in Olympic Games']  Male       ['france']       80315
# 84635  ['Competed in Olympic Games']  Male  ['switzerland']       85309
#
#                     Name  Height (cm)  Weight (kg)   Born_Date   Died_Date  \
# 16309        Ahmed Salem        177.0         70.0         NaN         NaN
# 24613        Ahmed Salem        178.0         73.0         NaN         NaN
# 25396  Nikolaos Kaloudis        178.0         73.0  1899-01-01         NaN
# 53599  Nikolaos Kaloudis        186.0         86.0  1899-01-01         NaN
# 67689     Georges Dubois        180.0         71.0         NaN  1934-01-01
# 79675     Georges Dubois        168.0         63.0         NaN         NaN
# 84635     Georges Dubois        177.0         77.0  1935-05-19  2018-09-08
#
#        Is_Alive          Born_City Born_Region Born_Country  Height_Imputed  \
# 16309      True                NaN         NaN          EGY            True
# 24613      True                NaN         NaN          EGY            True
# 25396      True                NaN         NaN          GRC            True
# 53599      True                NaN         NaN          GRC            True
# 67689     False                NaN         NaN          FRA            True
# 79675      True                NaN         NaN          FRA            True
# 84635     False  La Chaux-de-Fonds  Neuchâtel           SUI           False
#
#        Weight_Imputed  Born_Country_From_NOC
# 16309            True                   True
# 24613            True                   True
# 25396            True                   True
# 53599            True                   True
# 67689            True                   True
# 79675            True                   True
# 84635           False                  False

# %%
# Exact duplicates
dupes = bios_df[bios_df.duplicated()]
print(f"Exact duplicates: {len(dupes)}")

# Potential duplicates (same Name + Born_Date or Athlete_Id)
possible_dupes = bios_df[bios_df.duplicated(subset=['Name', 'Born_Date'], keep=False)]
print(f"possible duplicates: {len(possible_dupes)}")
# Out:
# Exact duplicates: 0
# possible duplicates: 8

# %%
def is_list_of_strings(x):
    return all(isinstance(r, str) for r in x)

no_duplicate_name_birth = pa.Check(
    lambda df: ~df.duplicated(subset=["Name", "Born_Date"]),
    element_wise=False,
    error="Duplicate athlete records found with same Name and Born_Date."
)

date_logic = pa.Check(
    lambda df: (df["Born_Date"].isna() | df["Died_Date"].isna()) | (df["Died_Date"] >= df["Born_Date"]),
    element_wise=False,
    error="Died_Date earlier than Born_Date."
)


height_weight_logic = pa.Check(
    lambda df: (
        (df["Weight (kg)"] / ((df["Height (cm)"] / 100) ** 2)).between(15, 45)
    ),
    error="Unrealistic height-to-weight ratio."
)

# %%
bio_schema = pa.DataFrameSchema(
    { 
        "Athlete_Id": pa.Column(int, pa.Check.ge(1), nullable=False, unique=True), 
        "Name": pa.Column(str, nullable=False), 
        "Sex": pa.Column(str, pa.Check.isin(["Male", "Female"]), nullable=False), 
        "NOC": pa.Column(str, pa.Check(is_list_of_strings, element_wise=False ), nullable=True),

        "Height (cm)": pa.Column(float, pa.Check.between(100,250), nullable=True), 
        "Weight (kg)": pa.Column(float, pa.Check.between(25,200), nullable=True), 
        "Height_Imputed": pa.Column(bool, nullable=False),
        "Weight_Imputed": pa.Column(bool, nullable=False),

        "Born_Date": pa.Column("datetime64[ns]", nullable=True), 
        "Died_Date": pa.Column("datetime64[ns]", nullable=True),
        'Is_Deceased': pa.Column(bool, nullable=False),

        "Born_City": pa.Column(str, nullable=True), 
        "Born_Region": pa.Column(str, nullable=True), 
        "Born_Country": pa.Column(str, pa.Check.str_length(3, 3), nullable=True), 
        "Born_Country_From_NOC": pa.Column(bool, nullable=False),

        "Roles": pa.Column(object,pa.Check(is_list_of_strings, element_wise=False ), nullable=True) 
        
        }, 
        strict=True, 
        coerce=True,
        
        checks=[

            no_duplicate_name_birth,
            date_logic,
            height_weight_logic

            ]

        ) 



try: 
    bio_schema.validate(bios_df, lazy=True) 
    print("Validation PASSED!") 
    
except pa.errors.SchemaErrors as exc: 
    print("Validation FAILED!") 
    error_df = exc.failure_cases
    print(exc)
# Out:
# Validation FAILED!
# {
#     "SCHEMA": {
#         "COLUMN_NOT_IN_SCHEMA": [
#             {
#                 "schema": null,
#                 "column": null,
#                 "check": "column_in_schema",
#                 "error": "column 'Is_Alive' not in DataFrameSchema {'Athlete_Id': <Schema Column(name=Athlete_Id, type=DataType(int64))>, 'Name': <Schema Column(name=Name, type=DataType(str))>, 'Sex': <Schema Column(name=Sex, type=DataType(str))>, 'NOC': <Schema Column(name=NOC, type=DataType(str))>, 'Height (cm)': <Schema Column(name=Height (cm), type=DataType(float64))>, 'Weight (kg)': <Schema Column(name=Weight (kg), type=DataType(float64))>, 'Height_Imputed': <Schema Column(name=Height_Imputed, type=DataType(bool))>, 'Weight_Imputed': <Schema Column(name=Weight_Imputed, type=DataType(bool))>, 'Born_Date': <Schema Column(name=Born_Date, type=DataType(datetime64[ns]))>, 'Died_Date': <Schema Column(name=Died_Date, type=DataType(datetime64[ns]))>, 'Is_Deceased': <Schema Column(name=Is_Deceased, type=DataType(bool))>, 'Born_City': <Schema Column(name=Born_City, type=DataType(str))>, 'Born_Region': <Schema Column(name=Born_Region, type=DataType(str))>, 'Born_Country': <Schema Column(name=Born_Country, type=DataType(str))>, 'Born_Country_From_NOC': <Schema Column(name=Born_Country_From_NOC, type=DataType(bool))>, 'Roles': <Schema Column(name=Roles, type=DataType(object))>}"
#             }
#         ],
#         "COLUMN_NOT_IN_DATAFRAME": [
#             {
#                 "schema": null,
#                 "column": null,
#                 "check": "column_in_dataframe",
#                 "error": "column 'Is_Deceased' not in dataframe. Columns in dataframe: ['Roles', 'Sex', 'NOC', 'Athlete_Id', 'Name', 'Height (cm)', 'Weight (kg)', 'Born_Date', 'Died_Date', 'Is_Alive', 'Born_City', 'Born_Region', 'Born_Country', 'Height_Imputed', 'Weight_Imputed', 'Born_Country_From_NOC']"
#             }
#         ]
#     },
#     "DATA": {
#         "DATAFRAME_CHECK": [
#             {
#                 "schema": null,
#                 "column": null,
#                 "check": "Duplicate athlete records found with same Name and Born_Date.",
#                 "error": "DataFrameSchema 'None' failed element-wise validator number 0: <Check <lambda>: Duplicate athlete records found with same Name and Born_Date.> failure cases: ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], Male, Male, Male, Male, ['egypt'], ['greece'], ['france'], ['france'], 24803, 54085, 80315, 80349, Ahmed Salem, Nikolaos Kaloudis, Georges Dubois,  Favier, 178.0, 186.0, 168.0, 168.0, 73.0, 86.0, 63.0, 63.0, 1899-01-01 00:00:00, True, True, True, True, EGY, GRC, FRA, FRA, True, True, True, True, True, True, True, True, True, True, True, True"
#             },
#             {
#                 "schema": null,
#                 "column": null,
#                 "check": "Unrealistic height-to-weight ratio.",
#                 "error": "DataFrameSchema 'None' failed element-wise validator number 2: <Check <lambda>: Unrealistic height-to-weight ratio.> failure cases: ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games', 'Other'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games', 'Other'], ['Competed in Olympic Games', 'Other'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games', 'Other'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games', 'Other'], ['Competed in Olympic Games', 'Other'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games', 'Other'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], ['Competed in Olympic Games'], Male, Male, Male, Male, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Female, Male, Male, Male, Female, Male, Male, Male, Male, Male, Male, Male, Male, Male, Male, Male, Female, Female, Female, Female, Female, Female, Male, Male, Male, Female, Female, Male, Female, Male, Male, Male, Female, Female, Female, Female, Male, Male, Female, Female, Female, Female, Female, Female, Male, Female, Female, Female, Female, Female, Female, Female, Female, Male, Male, Male, ['malawi'], ['zimbabwe'], ['tajikistan'], ['united states'], ['belgium'], ['belarus'], ['belarus'], ['spain'], ['spain'], ['spain'], ['spain'], ['spain'], ['spain'], ['spain'], ['finland'], ['france'], ['france'], ['greece'], ['poland'], [\"democratic people's republic of korea\"], ['russian federation'], ['czechoslovakia'], ['ukraine'], ['egypt'], ['australia'], ['canada'], ['france'], ['belgium'], ['czechoslovakia'], ['soviet union'], ['soviet union'], ['ecuador'], ['poland'], ['united states'], ['jamaica'], ['brazil'], ['djibouti'], ['dominican republic'], ['canada'], ['spain'], ['spain'], ['germany'], ['greece'], ['japan'], ['ukraine'], ['united kingdom'], ['cameroon'], ['ukraine'], ['nauru'], ['nauru'], ['burundi'], ['russian federation'], ['spain'], ['venezuela'], ['germany'], ['sou ...
#             }
#         ]
#     }
# }

# %%
error_df
# Out:
#        schema_context     column  \
# 0     DataFrameSchema      Roles
# 807   DataFrameSchema  Born_City
# 805   DataFrameSchema  Born_City
# 804   DataFrameSchema  Born_City
# 803   DataFrameSchema  Born_City
# ...               ...        ...
# 400   DataFrameSchema       Name
# 399   DataFrameSchema       Name
# 398   DataFrameSchema       Name
# 397   DataFrameSchema       Name
# 1201  DataFrameSchema       None
#
#                                                   check check_number  \
# 0     Duplicate athlete records found with same Name...            0
# 807                 Unrealistic height-to-weight ratio.            2
# 805                 Unrealistic height-to-weight ratio.            2
# 804                 Unrealistic height-to-weight ratio.            2
# 803                 Unrealistic height-to-weight ratio.            2
# ...                                                 ...          ...
# 400                 Unrealistic height-to-weight ratio.            2
# 399                 Unrealistic height-to-weight ratio.            2
# 398                 Unrealistic height-to-weight ratio.            2
# 397                 Unrealistic height-to-weight ratio.            2
# 1201                                column_in_dataframe         None
#
#                        failure_case   index
# 0     ['Competed in Olympic Games']   24613
# 807                               ?  115052
# 805                           Wuhan  114682
# 804                       Cape Town  106747
# 803                 Moskva (Moscow)  106742
# ...                             ...     ...
# 400               Carolina Malchair   90571
# 399               Emilie Livingston   90534
# 398                    Miguel Núñez   66381
# 397                 Hoche Yaya Aden   66354
# 1201                    Is_Deceased    None
#
# [1202 rows x 6 columns]

# %%
affiliation_schema = pa.DataFrameSchema(
    { 
        "Affiliation_Id": pa.Column(int, pa.Check.ge(0), nullable=False, unique=True), 

        "Affiliation_Club": pa.Column(str, nullable=True), 
        "Affiliation_City": pa.Column(str, nullable=True), 
        "Affiliation_Country": pa.Column(str, pa.Check.str_length(3, 3), nullable=True), 

        }, 
        strict=True, 
        coerce=True) 


try: 
    
    affiliation_schema.validate(affiliation_df, lazy=True) 
    print("Validation PASSED!") 
    
except pa.errors.SchemaErrors as exc: 
    print("Validation FAILED!") 
    error_df = exc.failure_cases
    print(exc)
# Out:
# Validation FAILED!
# {
#     "DATA": {
#         "DATAFRAME_CHECK": [
#             {
#                 "schema": null,
#                 "column": "Affiliation_Country",
#                 "check": "str_length(3, 3)",
#                 "error": "Column 'Affiliation_Country' failed element-wise validator number 0: str_length(3, 3) failure cases: MN, MO, Central Sport Klub Army, HCAW, Oder) (GER, Saale) (GER, Saale) (GER, Oder), Frankfurt (Oder) (GER, Oder) (GER, Alma-Ata, Salamanca, Campinas, CSKA, Tr\u00eas Coroas, Young Men's Christian Association, Vassoras, RJ, Steinfeld) (GER, Westfalen) (GER, Ohm) (GER, SP, Leningrad, 08, Leningrad, Durazno, SCHC, HHIJC, BHMC, EMHC, Tameside, Young Men's Christian Association, Campinas, Cairo, Saale) (GER, Young Men's Christian Association, Young Men's Christian Association, Young Men's Christian Association, Oder) (GER, Flanders, NJ, NJJK, Cairo, Young Men's Christian Association, 96, Central Sport Klub Navy, Oder) (GER, Baden) (GER, 92, 00, DZ&PC, AZ 1870, Central Sport Klub Navy), St. Petersburg (Leningrad, 84, Young Men's Christian Association, MN, Young Men's Christian Association, Young Men's Christian Association, Young Men's Christian Association, Young Men's Christian Association, Young Men's Christian Association, AMVJ, HZC de Robben, Alma-Ata, Young Men's Christian Association, UISP, AZ&PC, HZ&PC, Vienna) (AUT, Central Sport Klub Armee, Young Men's Christian Association, Young Men's Christian Association, Saale) (GER, Baden) (GER, Oder) (GER, VV. FF., Young Men's Christian Association, Young Men's Christian Association, S\u00e3o Caetano do Sul, Central Sport Klub Army, 92, 96, adidas, Manresa, Young Men's Christian Association, Oder) (GER, Saale) (GER, Saale) (GER, Saale) (GER, CIKO '66, ATC '75, North Island, SATUS, 96, 00-04, Young Men's Christian Association, Young Men's Christian Association, CUNY, Young Men's Christian Association, Young Men's Christian Association, Young Men's Hebrew Association, Young Men's Christian Association, DKIJV, IHCL, Upland) (GER, Central Sports Klub Armee, Upland) (GER, Our Lady of the Lake University, Saale) (GER, Oder) (GER, Independiente, Akashi - Hyogo, Akashi-Hyogo, Westfalen) (GER, Alma-Ata, Oder) (GER, CRO), Sl\u00e1via UK Bratislava (SVK, Minnesota, Aomori Forest Association, Army, SZKE, Mettmenstetten, Ebnat-Kappel, 04, 08, Leningrad, Leningrad, AV '34, PE, Kalenjin, Oder), Frankfurt (Oder) (GER, Saale) (GER, Cairo, SOP), Bishkek (KGZ, Leningrad, PAC), Rotterdam (NED, Harz) (GER, Getafe), La Bastida (Toledo, NYAC, Baden) (GER, TIGAR), Wheat Ridge (USA, Sdusor) No.81 Babushkino, Moskva (RUS, LTU), SK S\u0117km\u0117s trasa, Ignalina (LTU, Coral Gables, FL, USA, Oldenburg) (GER, Mecca) (KSA, Ohm) (GER, Murcia, ESP, ASC), Windhoek (NAM, PNSC), Fort McMurray (CAN, Tirana, ALB, Antigua and Barbuda, Brazil, Aruba, Brisbane, QLD, AUS, Brisbane, QLD, AUS, Perth, WA, AUS, Australia, Australia, Australia, Brisbane, QLD, AUS, Austria, Austin, TX, USA, Bermuda, Miami, FL, USA, Santos, BRA, Bulgaria, France, Canada, Canada, CAMO, Canada, Toronto, ON, CAN, Kelowna, BC, CAN, Canada, England, People's Republic of China, People's Republic of China, People's Republic of China, Shanghai, CHN, People's Republic of China, People's Republic of China, People's Republic of China, People's Republic of China, People's Republic of China, People's Republic of China, Guangzhou, CHN, Taiyuan, CHN, Nanjing, CHN, People's Republic of China, Brescia, ITA, HPK) (Auckland, NZL, CRP) (Cali, COL, Cyprus, Czech Republic, Denmark, Barcelona, ESP, Spain, Spain, Tallinn, EST, France, France, France, France, Montpellier, FRA, Scotland, Wales, (GRE, Greece, Athens, GRE, Guyana, Scotland, Honduras, Hungary, Nagykanizsa, HUN, CAN) (Canada, Israel, Italy, ITA) (Italy, Italy, Italy, Rome, ITA, Bologna, ITA, Italy, Japan, Japan, Japan, Japan, Japan, Japan, Tokyo, JPN, Japan, Tokyo, JPN, Daejeon, KOR, Republic of Korea, Riga, LAT, Kosovo, Tavistock, GBR, Morocco, Las Cruces, NM, USA, Eindhoven, NED, Eindhoven, NED, Netherlands, Amsterdam, NED, London, GBR, Canada, England, Poland, Romania, Russian Federation, St. Petersburg, RUS, Turin, ITA, Brisbane, QLD, AUS, Slovenia, Slovenia, Serbia, Colombo, SR ...
#             }
#         ]
#     }
# }

# %%
bios_df[bios_df['Height_Imputed']==True][['Height (cm)','Height_Imputed','Sex','Name']].sample(10)
# Out:
#        Height (cm)  Height_Imputed     Sex                     Name
# 23325        180.0            True    Male              Václav Rais
# 14510        178.0            True    Male             Eduard Gusev
# 41612        175.0            True    Male              Emil Collan
# 4810         172.0            True    Male            Gunnar Hansen
# 18647        177.0            True    Male            Harry Freeman
# 50560        170.0            True  Female  Eleanor Garatti-Saville
# 14281        177.0            True    Male          Kristian Frisch
# 85258        178.0            True    Male            Nigel Gardner
# 67749        180.0            True    Male             Jean Gérault
# 31098        168.0            True    Male              P. Gussmann

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308905 entries, 0 to 308904
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Event       308905 non-null  object
#  1   Team        121932 non-null  object
#  2   Medal       44199 non-null   object
#  3   As          308905 non-null  object
#  4   NOC         308905 non-null  object
#  5   Discipline  308905 non-null  object
#  6   Athlete_Id  308905 non-null  int64
#  7   Game Year   308904 non-null  float64
#  8   Game Type   308904 non-null  object
#  9   Position    283633 non-null  float64
#  10  Tied        307080 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 25.9+ MB

# %%
results_df
# Out:
#                                     Event                 Team Medal  \
# 0                  Singles, Men (Olympic)                  NaN   NaN
# 1                  Doubles, Men (Olympic)      Guillaume Raoux   NaN
# 2                  Singles, Men (Olympic)                  NaN   NaN
# 3                  Doubles, Men (Olympic)       Jean Montariol   NaN
# 4                  Singles, Men (Olympic)                  NaN   NaN
# ...                                   ...                  ...   ...
# 308900               Four, Open (Olympic)  Republic of Korea 2   NaN
# 308901          Basketball, Men (Olympic)                 Cuba   NaN
# 308902  400 metres Hurdles, Men (Olympic)                  NaN   NaN
# 308903        Ice Hockey, Women (Olympic)                  ROC   NaN
# 308904          Water Polo, Men (Olympic)            Australia   NaN
#
#                            As  NOC               Discipline  Athlete_Id  \
# 0              Arnaud Boetsch  FRA                   Tennis           2
# 1              Arnaud Boetsch  FRA                   Tennis           2
# 2       Jean-François Blanchy  FRA                   Tennis           1
# 3       Jean-François Blanchy  FRA                   Tennis           1
# 4       Jean-François Blanchy  FRA                   Tennis           1
# ...                       ...  ...                      ...         ...
# 308900           Shin Ye-Chan  KOR    Bobsleigh (Bobsleigh)      149217
# 308901  Carlos García-Ordóñez  CUB  Basketball (Basketball)      149219
# 308902         André Foussard  FRA                Athletics      149225
# 308903    Valeriya Merkusheva  ROC  Ice Hockey (Ice Hockey)      149223
# 308904          Bill Phillips  AUS    Water Polo (Aquatics)      149814
#
#         Game Year        Game Type  Position   Tied
# 0          1996.0  Summer Olympics      17.0   True
# 1          1996.0  Summer Olympics      17.0   True
# 2          1912.0  Summer Olympics      17.0   True
# 3          1912.0  Summer Olympics       NaN  False
# 4          1920.0  Summer Olympics      32.0   True
# ...           ...              ...       ...    ...
# 308900     2022.0  Winter Olympics      25.0  False
# 308901     1952.0  Summer Olympics      13.0   True
# 308902     1924.0  Summer Olympics       5.0  False
# 308903     2022.0  Winter Olympics       5.0  False
# 308904     1948.0  Summer Olympics       NaN  False
#
# [308905 rows x 11 columns]

# %%
df_nan_percentage(results_df)
# Out:
# Medal         85.69%
# Team          60.53%
# Position       8.18%
# Tied           0.59%
# Event           0.0%
# As              0.0%
# NOC             0.0%
# Athlete_Id      0.0%
# Discipline      0.0%
# Game Type       0.0%
# Game Year       0.0%
# dtype: object

# %%
# --- Schema Definition ---
fact_events_schema = pa.DataFrameSchema(
    {

        "Athlete_Id": pa.Column(int, pa.Check.ge(1), nullable=False),
        "As":   pa.Column(str, nullable=False),
        "NOC": pa.Column(str, pa.Check.str_length(3, 3), nullable=False),
        "Discipline": pa.Column(str, nullable=False),
        "Game Type": pa.Column(str, nullable=True),
        "Game Year": pa.Column(float, pa.Check.between(1896, 2024), nullable=True),


        "Event": pa.Column(str, nullable=True),
        "Team": pa.Column(str, nullable=True),
        "Tied": pa.Column(bool, nullable=True),


        "Position": pa.Column(float,pa.Check.ge(1), nullable=True),
        "Medal": pa.Column(
            str,
            pa.Check.isin(["Gold", "Silver", "Bronze"]),
            nullable=True
        ),

    },
    strict=True,
    coerce=True,
    # checks=[

    # ],
    name="fact_events_schema"
)

# --- Validation ---
try:
    fact_events_schema.validate(results_df, lazy=True)
    print("Validation PASSED!")
except pa.errors.SchemaErrors as exc:
    print("Validation FAILED!")
    error_df = exc.failure_cases
    print(exc)
# Out:
# Validation PASSED!

# %%
def rename_df_columns(df, names_dict):
    df = df.copy()
    df = df.rename(columns= names_dict)
    return df

# %%
events_fact_table_columns_names =\
{
    "Athlete_Id": "athlete_id",
    "As": "dim_as",
    "NOC": "dim_noc",
    "Discipline": "dim_discipline",
    "Game Type": "dim_game_type",
    "Game Year": "dim_game_year",
    "Event": "d_event_name",
    "Team": "d_team_name",
    "Tied": "m_tied_flag",
    "Position":"m_position",
    "Medal":"m_medal"

}

athlete_dim_table_columns_names =\
{
    "Athlete_Id": "athlete_id",
    "Roles": "athlete_roles",
    "Sex": "athlete_sex",
    "NOC": "athlete_NOC",
    "Name": "athlete_name",
    "Height (cm)": "athlete_height_cm",
    "Weight (kg)": "athlete_weight_kg",
    "Born_Date": "athlete_born_date",
    "Died_Date":"athlete_died_date",
    "Is_Alive":"athlete_is_alive",
    "Born_City":"athlete_born_city",
    "Born_Region":"athlete_born_region",
    "Born_Country":"athlete_born_country",
    "Height_Imputed":"athlete_is_height_imputed",
    "Weight_Imputed":"athlete_is_weight_imputed",
    "Born_Country_From_NOC":"athlete_is_born_country_from_NOC"

}

# %%
rename_df_columns(results_df, events_fact_table_columns_names)
# Out:
#                              d_event_name          d_team_name m_medal  \
# 0                  Singles, Men (Olympic)                  NaN     NaN
# 1                  Doubles, Men (Olympic)      Guillaume Raoux     NaN
# 2                  Singles, Men (Olympic)                  NaN     NaN
# 3                  Doubles, Men (Olympic)       Jean Montariol     NaN
# 4                  Singles, Men (Olympic)                  NaN     NaN
# ...                                   ...                  ...     ...
# 308900               Four, Open (Olympic)  Republic of Korea 2     NaN
# 308901          Basketball, Men (Olympic)                 Cuba     NaN
# 308902  400 metres Hurdles, Men (Olympic)                  NaN     NaN
# 308903        Ice Hockey, Women (Olympic)                  ROC     NaN
# 308904          Water Polo, Men (Olympic)            Australia     NaN
#
#                        dim_as dim_noc           dim_discipline  athlete_id  \
# 0              Arnaud Boetsch     FRA                   Tennis           2
# 1              Arnaud Boetsch     FRA                   Tennis           2
# 2       Jean-François Blanchy     FRA                   Tennis           1
# 3       Jean-François Blanchy     FRA                   Tennis           1
# 4       Jean-François Blanchy     FRA                   Tennis           1
# ...                       ...     ...                      ...         ...
# 308900           Shin Ye-Chan     KOR    Bobsleigh (Bobsleigh)      149217
# 308901  Carlos García-Ordóñez     CUB  Basketball (Basketball)      149219
# 308902         André Foussard     FRA                Athletics      149225
# 308903    Valeriya Merkusheva     ROC  Ice Hockey (Ice Hockey)      149223
# 308904          Bill Phillips     AUS    Water Polo (Aquatics)      149814
#
#         dim_game_year    dim_game_type  m_position m_tied_flag
# 0              1996.0  Summer Olympics        17.0        True
# 1              1996.0  Summer Olympics        17.0        True
# 2              1912.0  Summer Olympics        17.0        True
# 3              1912.0  Summer Olympics         NaN       False
# 4              1920.0  Summer Olympics        32.0        True
# ...               ...              ...         ...         ...
# 308900         2022.0  Winter Olympics        25.0       False
# 308901         1952.0  Summer Olympics        13.0        True
# 308902         1924.0  Summer Olympics         5.0       False
# 308903         2022.0  Winter Olympics         5.0       False
# 308904         1948.0  Summer Olympics         NaN       False
#
# [308905 rows x 11 columns]

# %%
rename_df_columns(bios_df, athlete_dim_table_columns_names)
# Out:
#                                          athlete_roles athlete_sex  \
# 0                        ['Competed in Olympic Games']        Male
# 1                        ['Competed in Olympic Games']        Male
# 2       ['Competed in Olympic Games', 'Administrator']        Male
# 3                        ['Competed in Olympic Games']        Male
# 4                        ['Competed in Olympic Games']        Male
# ...                                                ...         ...
# 145560                   ['Competed in Olympic Games']        Male
# 145561                   ['Competed in Olympic Games']        Male
# 145562                   ['Competed in Olympic Games']        Male
# 145563                   ['Competed in Olympic Games']      Female
# 145564                ['Non-starter', 'Administrator']        Male
#
#                   athlete_NOC  athlete_id           athlete_name  \
# 0                  ['france']           2         Arnaud Boetsch
# 1                  ['france']           1  Jean-François Blanchy
# 2                  ['france']           3           Jean Borotra
# 3                  ['france']           5           Albert Canet
# 4                  ['france']           4        Jacques Brugnon
# ...                       ...         ...                    ...
# 145560  ['republic of korea']      149217            Sin Ye-Chan
# 145561               ['cuba']      149219  Carlos García-Ordóñez
# 145562             ['france']      149225         André Foussard
# 145563                ['roc']      149223    Valeriya Merkusheva
# 145564          ['australia']      149814          Bill Phillips
#
#         athlete_height_cm  athlete_weight_kg athlete_born_date  \
# 0                   183.0               76.0        1969-04-01
# 1                   185.0               79.0        1886-12-12
# 2                   183.0               76.0        1898-08-13
# 3                   185.0               79.0        1878-04-17
# 4                   168.0               64.0        1895-05-11
# ...                   ...                ...               ...
# 145560              182.0               90.0        1995-06-13
# 145561              194.0               90.0        1927-04-24
# 145562              166.0               71.0        1899-05-19
# 145563              168.0               65.0        1999-09-20
# 145564              186.0               86.0        1913-07-15
#
#        athlete_died_date  athlete_is_alive   athlete_born_city  \
# 0                    NaN              True              Meulan
# 1             1960-10-02             False            Bordeaux
# 2             1994-07-17             False            Biarritz
# 3             1930-07-25             False          Wandsworth
# 4             1978-03-20             False         Paris VIIIe
# ...                  ...               ...                 ...
# 145560               NaN              True                 NaN
# 145561        2019-11-24             False  La Habana (Havana)
# 145562        1986-03-18             False               Niort
# 145563               NaN              True     Moskva (Moscow)
# 145564        2003-10-20             False        Dulwich Hill
#
#           athlete_born_region athlete_born_country  athlete_is_height_imputed  \
# 0                   Yvelines                   FRA                      False
# 1                    Gironde                   FRA                       True
# 2       Pyrénées-Atlantiques                   FRA                      False
# 3                    England                   GBR                       True
# 4                      Paris                   FRA                      False
# ...                       ...                  ...                        ...
# 145560                    NaN                 None                       True
# 145561   Ciudad de La Habana                   CUB                       True
# 145562           Deux-Sèvres                   FRA                      False
# 145563                Moskva                   RUS                      False
# 145564       New South Wales                   AUS                       True
#
#         athlete_is_weight_imputed  athlete_is_born_country_from_NOC
# 0                           False                             False
# 1                            True                             False
# 2                           False                             False
# 3                            True                             False
# 4                           False                             False
# ...                           ...                               ...
# 145560                       True                              True
# 145561                       True                             False
# 145562                       True                             False
# 145563                      False                             False
# 145564                       True                             False
#
# [145565 rows x 16 columns]

# %%
# Out:
# Validation PASSED!

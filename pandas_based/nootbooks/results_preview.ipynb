# %%
import pandas as pd

# %%
s3_endpoint = "http://localhost:9000" 

access_key = "accesskey"
secret_key = "secretkey"

bronze_bucket = "bronze"
silver_bucket = "silver"
gold_bucket = "gold"

s3fs_opts = {
    "key": access_key,
    "secret": secret_key,
    "client_kwargs": {"endpoint_url": s3_endpoint},
}

# %%
def df_nan_percentage(df):
    """Return a Series showing percentage of NaN values per column."""

    return df.isna().mean().mul(100).round(2).sort_values(ascending=False).map(lambda x: f"{x}%")

# %% [markdown]
# # Raw Data Sample

# %%
bios_raw_data_df = pd.read_parquet(f"s3://{bronze_bucket}/raw_data/biodata.parquet", storage_options=s3fs_opts)
editions_raw_data_df = pd.read_parquet(f"s3://{bronze_bucket}/raw_data/editions.parquet", storage_options=s3fs_opts)
results_raw_data_df = pd.read_parquet(f"s3://{bronze_bucket}/raw_data/results.parquet", storage_options=s3fs_opts)

# %% [markdown]
# **Bios Raw Data:**

# %%
bios_raw_data_df.sample(5)
# Out:
#                             Roles     Sex                        Full name  \
# 142546  Competed in Olympic Games  Female  Yevgeniya Andreyevna•Kosetskaya
# 114993  Competed in Olympic Games    Male        Tigran Gevorg•Martirosyan
# 89502   Competed in Olympic Games    Male                      Nam•Sung-Ho
# 94379   Competed in Olympic Games    Male                      Kim•In-Seop
# 37547   Competed in Olympic Games    Male                     Arthur•Heyne
#
#                         Used name  \
# 142546       Yevgeniya•Kosetskaya
# 114993  Tigran Gevorg•Martirosyan
# 89502                 Nam•Sung-Ho
# 94379                 Kim•In-Seop
# 37547                Arthur•Heyne
#
#                                                      Born  Died  \
# 142546  16 December 1994 in Chelyabinsk, Chelyabinsk (...  <NA>
# 114993                9 June 1988 in Gyumri, Shirak (ARM)  <NA>
# 89502                                     10 October 1975  <NA>
# 94379                  2 March 1973 in Daegu, Daegu (KOR)  <NA>
# 37547   25 August 1946 in Kaiserslautern, Rheinland-Pf...  <NA>
#
#                       NOC  Athlete_Id                           Affiliations  \
# 142546                ROC      146099                                   <NA>
# 114993            Armenia      116329                                   <NA>
# 89502   Republic of Korea       90221                                   <NA>
# 94379   Republic of Korea       95145  Samsung Life Sports Club, Seoul (KOR)
# 37547        West Germany       37845              WSV Godesberg, Bonn (GER)
#
#        Nick/petnames    Measurements Title(s) Nationality Other names  \
# 142546          <NA>            <NA>     <NA>        <NA>        <NA>
# 114993          <NA>           69 kg     <NA>        <NA>        <NA>
# 89502           <NA>  181 cm / 79 kg     <NA>        <NA>        <NA>
# 94379           <NA>  160 cm / 58 kg     <NA>        <NA>  Kim In-Sub
# 37547           <NA>  184 cm / 82 kg     <NA>        <NA>        <NA>
#
#                      Original name Name order
# 142546  Евгения Андреевна•Косецкая       <NA>
# 114993    Տիգրան Գևորգ•Մարտիրոսյան       <NA>
# 89502                         <NA>   Oriental
# 94379                         김•인섭   Oriental
# 37547                         <NA>       <NA>

# %% [markdown]
# **Results Raw Data:**

# %%
results_raw_data_df.sample(5)
# Out:
#                        Games                                     Event  \
# 165282  1908 Summer Olympics         Standing High Jump, Men (Olympic)
# 35992   1988 Summer Olympics                     Hockey, Men (Olympic)
# 61021   1956 Summer Olympics                Horse Vault, Men (Olympic)
# 152716  1976 Summer Olympics       4 × 400 metres Relay, Men (Olympic)
# 256120  2014 Winter Olympics  15 kilometres Skiathlon, Women (Olympic)
#
#                            Team  Pos Medal                    As  NOC  \
# 165282                     <NA>   16  <NA>       Martin Sheridan  USA
# 35992              Soviet Union    7  <NA>        Igor Yulchiyev  URS
# 61021                      <NA>  =41  <NA>        Raimo Heinonen  FIN
# 152716  Kingdom of Saudi Arabia  DNS  <NA>  Mohamed Ali Al-Malky  KSA
# 256120                     <NA>   13  <NA>    Krista Lähteenmäki  FIN
#
#                               Discipline  Athlete_Id Nationality Unnamed: 7
# 165282                         Athletics       79031        <NA>       None
# 35992                             Hockey       20316        <NA>       None
# 61021   Artistic Gymnastics (Gymnastics)       29777        <NA>       None
# 152716                         Athletics       73000        <NA>       None
# 256120     Cross Country Skiing (Skiing)      118787        <NA>       None

# %% [markdown]
# **Games Raw Data:**

# %%
editions_raw_data_df.head()
# Out:
#      #  Year       City Country   Opened    Closed            Competition  \
# 0    I  1896     Athina     GRE  6 April  15 April           6 – 13 April
# 1   II  1900      Paris     FRA     <NA>      <NA>    14 May – 28 October
# 2  III  1904  St. Louis     USA   14 May      <NA>   1 July – 26 November
# 3   IV  1908     London     GBR  13 July   25 July  27 April – 31 October
# 4    V  1912  Stockholm     SWE   6 July   15 July        5 May – 27 July
#
#   Unnamed: 7      Game_Type Edition_Name
# 0       <NA>  Olympic Games       Summer
# 1       <NA>  Olympic Games       Summer
# 2       <NA>  Olympic Games       Summer
# 3       <NA>  Olympic Games       Summer
# 4       <NA>  Olympic Games       Summer

# %% [markdown]
# **Scrape Failures Logs:**

# %%
scrape_failures_df = pd.read_parquet(f"s3://{bronze_bucket}/scrape_failures/failed_athletes.parquet", storage_options=s3fs_opts)

# %%
scrape_failures_df.sample(5)
# Out:
#       failed_athlete_id                  error_message
# 4086             149664  Status 404 for athlete 149664
# 4270             149845  Status 404 for athlete 149845
# 870              102274  Status 404 for athlete 102274
# 3767             149342  Status 404 for athlete 149342
# 4350             149930  Status 404 for athlete 149930

# %% [markdown]
# # Cleaned Data Stage I

# %%
cleaned_biodata_df = pd.read_parquet(f"s3://{silver_bucket}/clean_data/cleaned_biodata.parquet", storage_options=s3fs_opts)
cleaned_affiliations_df = pd.read_parquet(f"s3://{silver_bucket}/clean_data/dim_affiliation.parquet", storage_options=s3fs_opts)
bridge_athlete_affiliation_df = pd.read_parquet(f"s3://{silver_bucket}/clean_data/bridge_athlete_affiliation.parquet", storage_options=s3fs_opts)
cleaned_editions_df = pd.read_parquet(f"s3://{silver_bucket}/clean_data/cleaned_editions.parquet", storage_options=s3fs_opts)
cleaned_results_df = pd.read_parquet(f"s3://{silver_bucket}/clean_data/cleaned_results.parquet", storage_options=s3fs_opts)

# %% [markdown]
# **Cleaned Bios Data:**

# %%
cleaned_biodata_df.sample(5)
# Out:
#                                     Roles     Sex             NOC  Athlete_Id  \
# 120770          Competed in Olympic Games    Male  united kingdom      122671
# 46672   Competed in Olympic Games,Referee  Female  united kingdom       47025
# 20216           Competed in Olympic Games  Female   united states       20360
# 34586     Competed in Olympic Games,Other    Male         hungary       34856
# 142762          Competed in Olympic Games  Female         romania      146323
#
#                   Name  Height (cm)  Weight (kg)  Born_Date Died_Date  \
# 120770    Peter Wilson        198.0         90.0 1986-09-15       NaT
# 46672   Lindsey Fraser        165.0         53.0 1958-01-24       NaT
# 20216     Anita Miller        172.0         61.0 1951-05-14       NaT
# 34586   János Martinek        175.0         69.0 1965-05-23       NaT
# 142762   Kriszta Incze        170.0          NaN 1996-05-15       NaT
#
#         Is_Alive        Born_City    Born_Region Born_Country
# 120770      True       Dorchester       England           GBR
# 46672       True         Woolwich       England           GBR
# 20216       True        Bryn Mawr  Pennsylvania           USA
# 34586       True         Budapest      Budapest           HUN
# 142762      True  Sfântu Gheorghe       Covasna           ROU

# %% [markdown]
# **Cleaned Afiliations Data:**

# %%
cleaned_affiliations_df.sample(5)
# Out:
#        Affiliation_Id                 Affiliation_Club Affiliation_City  \
# 32302           32302             Spordiklubi Biathlon             None
# 31850           31850            SG Stadtwerke München          München
# 35172           35172            Debreceni Sportiskola             None
# 25335           25335  Singapore Badminton Association             None
# 36766           36766            HC Bílí Tygři Liberec             None
#
#       Affiliation_Country
# 32302                None
# 31850                 GER
# 35172                None
# 25335                None
# 36766                 ELH

# %% [markdown]
# **Athlete - Affiliation Bridge Data:**

# %%
bridge_athlete_affiliation_df.sample(5)
# Out:
#         Athlete_Id  Affiliation_Id
# 23790        22785               0
# 59744        57229           13072
# 29515        28332            7302
# 119213      112707           27725
# 111041      105286           14741

# %% [markdown]
# **Cleaned Games Data:**

# %%
cleaned_editions_df.sample(5)
# Out:
#     Year       City Country      Opened      Closed             Comments  \
# 50  1996    Atlanta     USA  1996-07-19  1996-08-04                 <NA>
# 40  1976  Innsbruck     AUT  1976-02-04  1976-02-15                 <NA>
# 1   1870     Athina     GRE        None        None                 <NA>
# 20  1940   Helsinki     FIN        None        None  Not held due to war
# 62  2014    Nanjing     CHN  2014-08-16  2014-08-28                 <NA>
#
#                            Game_Type Edition_Name Competition_Start  \
# 50                     Olympic Games       Summer        1996-07-20
# 40                     Olympic Games       Winter        1976-02-03
# 1   Forerunners to the Olympic Games                           None
# 20                     Olympic Games       Summer              None
# 62               Youth Olympic Games       Summer        2014-08-14
#
#    Competition_End  Game_Id
# 50      1996-08-04       51
# 40      1976-02-15       41
# 1             None        2
# 20            None       21
# 62      2014-08-28       63

# %% [markdown]
# **Cleaned results Data:**

# %%
cleaned_results_df.sample(5)
# Out:
#                                           Event           Team Medal  \
# 5296                     Doubles, Men (Olympic)  František Týř  <NA>
# 194761                     Rings, Men (Olympic)           <NA>  <NA>
# 244468           Cross-Country, Women (Olympic)           <NA>  <NA>
# 301744  Lightweight, Freestyle, Women (Olympic)           <NA>  <NA>
# 140379             10,000 metres, Men (Olympic)           <NA>  <NA>
#
#                      As  NOC                        Discipline  Athlete_Id  \
# 5296         Otto Wofek  TCH                            Tennis        2663
# 194761      Víctor Cano  ESP  Artistic Gymnastics (Gymnastics)       91287
# 244468  Adelheid Morath  GER   Cycling Mountain Bike (Cycling)      113137
# 301744      Anshu Malik  IND                         Wrestling      143745
# 140379     Mariano Haro  ESP                         Athletics       67231
#
#         Game Year        Game Type  Position   Tied
# 5296         1920  Summer Olympics         9   True
# 194761       2000  Summer Olympics        52   True
# 244468       2008  Summer Olympics        18  False
# 301744       2020  Summer Olympics         9  False
# 140379       1972  Summer Olympics         4  False

# %% [markdown]
# # Cleaned Data Stage II

# %%
imputed_bios_df = pd.read_parquet(f"s3://{silver_bucket}/clean_data_II/cleaned_biodata.parquet", storage_options=s3fs_opts)
imputed_editions_df = pd.read_parquet(f"s3://{silver_bucket}/clean_data_II/cleaned_editions.parquet", storage_options=s3fs_opts)

# %% [markdown]
# **imputed Bios Data:**

# %%
imputed_bios_df.sample(5)
# Out:
#                                           Roles     Sex             NOC  \
# 45142                 Competed in Olympic Games    Male         belgium
# 103034                Competed in Olympic Games  Female  united kingdom
# 39750                 Competed in Olympic Games    Male  czechoslovakia
# 90015                 Competed in Olympic Games    Male          sweden
# 73570   Competed in Olympic Games,Administrator    Male          norway
#
#         Athlete_Id            Name  Height (cm)  Weight (kg)  Born_Date  \
# 45142        45491  Paul De Backer        184.0         77.0 1894-11-28
# 103034      104012   Laura Baldwin        170.0         63.0 1980-01-17
# 39750        40059  Petr Pulkrábek        178.0         74.0 1939-05-04
# 90015        90739   Pether Markne        175.0         68.0 1962-07-27
# 73570        74157    Charles Hoff        182.0         68.0 1902-05-09
#
#         Died_Date  Is_Alive             Born_City  \
# 45142  1963-01-09     False            Schaerbeek
# 103034        NaT      True                London
# 39750         NaT      True                  <NA>
# 90015         NaT      True      Turinge, Nykvarn
# 73570  1985-02-19     False  Glemmen, Fredrikstad
#
#                           Born_Region Born_Country  Height_Imputed  \
# 45142   Région de Bruxelles-Capitale           BEL            True
# 103034                       England           GBR           False
# 39750                            <NA>         None           False
# 90015                      Stockholm           SWE           False
# 73570                          Viken           NOR           False
#
#         Weight_Imputed  Born_Country_From_NOC
# 45142             True                  False
# 103034           False                  False
# 39750            False                   True
# 90015            False                  False
# 73570            False                  False

# %% [markdown]
# **imputed Games Data:**

# %%
imputed_editions_df.sample(5)
# Out:
#     Year                    City Country      Opened      Closed Comments  \
# 0   1859                  Athina     GRE        None        None     <NA>
# 15  1928            Sankt Moritz     SUI  1928-02-11  1928-02-17     <NA>
# 37  1972                 München     FRG  1972-08-26  1972-09-11     <NA>
# 19  1936  Garmisch-Partenkirchen     GER  1936-02-06  1936-02-16     <NA>
# 62  2014                 Nanjing     CHN  2014-08-16  2014-08-28     <NA>
#
#                            Game_Type Edition_Name Competition_Start  \
# 0   Forerunners to the Olympic Games                           None
# 15                     Olympic Games       Winter        1928-02-11
# 37                     Olympic Games       Summer        1972-08-26
# 19                     Olympic Games       Winter        1936-02-06
# 62               Youth Olympic Games       Summer        2014-08-14
#
#    Competition_End  Game_Id  Opened_Imputed  Closed_Imputed
# 0             None        1           False           False
# 15      1928-02-19       16           False           False
# 37      1972-09-11       38           False           False
# 19      1936-02-16       20           False           False
# 62      2014-08-28       63           False           False

# %% [markdown]
# # Missing Values Percentage Comparison

# %%
bios1 = pd.Series(df_nan_percentage(cleaned_biodata_df), name="Before Imputing")
bios2 = pd.Series(df_nan_percentage(imputed_bios_df), name="After Imputing")

games1 = pd.Series(df_nan_percentage(cleaned_editions_df), name="Before Imputing")
games2 = pd.Series(df_nan_percentage(imputed_editions_df), name="After Imputing")

# %% [markdown]
# **Bios Data:**

# %%
pd.concat([bios1, bios2], axis=1)
# Out:
#                       Before Imputing After Imputing
# Died_Date                      76.67%         76.67%
# Weight (kg)                    29.85%           0.0%
# Height (cm)                    26.69%           0.0%
# Born_City                      22.67%         22.67%
# Born_Country                   22.67%          4.56%
# Born_Region                    22.67%         22.67%
# Born_Date                       1.24%          1.24%
# Name                             0.0%           0.0%
# Sex                              0.0%           0.0%
# Roles                            0.0%           0.0%
# Athlete_Id                       0.0%           0.0%
# NOC                              0.0%           0.0%
# Is_Alive                         0.0%           0.0%
# Height_Imputed                    NaN           0.0%
# Weight_Imputed                    NaN           0.0%
# Born_Country_From_NOC             NaN           0.0%

# %% [markdown]
# **Games Data:**

# %%
pd.concat([games1, games2], axis=1)
# Out:
#                   Before Imputing After Imputing
# Comments                   93.42%         93.42%
# Closed                     21.05%         15.79%
# Opened                     19.74%         14.47%
# Competition_End            15.79%         15.79%
# Competition_Start          14.47%         14.47%
# Year                         0.0%           0.0%
# City                         0.0%           0.0%
# Country                      0.0%           0.0%
# Game_Type                    0.0%           0.0%
# Edition_Name                 0.0%           0.0%
# Game_Id                      0.0%           0.0%
# Opened_Imputed                NaN           0.0%
# Closed_Imputed                NaN           0.0%

# %% [markdown]
# # Data Quality Failure Cases

# %%
bios_failure_cases_df = pd.read_parquet(f"s3://{silver_bucket}/failure_cases/bios_failure_cases.parquet", storage_options=s3fs_opts)
affiliations_failure_cases_df = pd.read_parquet(f"s3://{silver_bucket}/failure_cases/affiliations_failure_cases.parquet", storage_options=s3fs_opts)
editions_failure_cases_df = pd.read_parquet(f"s3://{silver_bucket}/failure_cases/editions_failure_cases.parquet", storage_options=s3fs_opts)
results_failure_cases_df = pd.read_parquet(f"s3://{silver_bucket}/failure_cases/results_failure_cases.parquet", storage_options=s3fs_opts)

# %% [markdown]
# **Bios Data Quality Failure Cases:**

# %%
bios_failure_cases_df.sample(5)
# Out:
#     Athlete_Id  Born_Country_From_NOC  Height (cm)  Height_Imputed  Is_Alive  \
# 62      116419                  False        183.0           False      True
# 30       42066                   True        168.0           False      True
# 75      126756                  False        173.0           False      True
# 33       56889                  False        185.0           False     False
# 12       28292                  False        165.0           False      True
#
#               NOC                Name                            Roles  \
# 62      australia         Damon Kelly        Competed in Olympic Games
# 30         france  Françoise Decharne        Competed in Olympic Games
# 75  united states      Holley Mangold        Competed in Olympic Games
# 33   soviet union    Vasily Alekseyev  Competed in Olympic Games,Other
# 12          spain         Marta Baldó        Competed in Olympic Games
#
#        Sex  Weight (kg)  Weight_Imputed                 failed_check  \
# 62    Male        154.0           False  height_weight_ratio_invalid
# 30  Female         42.0           False  height_weight_ratio_invalid
# 75  Female        155.0           False  height_weight_ratio_invalid
# 33    Male        160.0           False  height_weight_ratio_invalid
# 12  Female         40.0           False  height_weight_ratio_invalid
#
#     Born_Date  Died_Date          Born_City  Born_Region Born_Country
# 62 1983-12-01        NaT           Atherton  Queensland           AUS
# 30 1963-05-20        NaT               <NA>         <NA>          FRA
# 75 1989-12-22        NaT          Kettering        Ohio           USA
# 33 1942-01-07 2011-11-25  Pokrovo-Shishkino      Ryazan           RUS
# 12 1979-04-08        NaT        Villajoyosa    Alicante           ESP

# %% [markdown]
# **Affiliations Data Quality Failure Cases:**

# %%
affiliations_failure_cases_df.sample(5)
# Out:
#            Affiliation_Club  Affiliation_Id  \
# 2234  Dynamiques de Brebeuf           34671
# 1507                  Kelme           28563
# 2140          Metz Handball           33805
# 1613               Asker SK           29866
# 2326      SC im Theresianum           35542
#
#                                   failed_check Affiliation_City  \
# 2234  duplicate_affiliation_with_different_ids         Montreal
# 1507  duplicate_affiliation_with_different_ids              ESP
# 2140  duplicate_affiliation_with_different_ids             None
# 1613  duplicate_affiliation_with_different_ids             None
# 2326  duplicate_affiliation_with_different_ids             None
#
#      Affiliation_Country
# 2234                None
# 1507                None
# 2140                None
# 1613                None
# 2326         Vienna, AUT

# %% [markdown]
# **Games Data Quality Failure Cases:**

# %%
editions_failure_cases_df.sample(5)
# Out:
#    Edition_Name                              failed_check  Year    City  \
# 4                isin(['Summer', 'Winter', 'Equestrian'])  1906  Athina
# 6                                     opened_after_closed  1870  Athina
# 7                                     opened_after_closed  1875  Athina
# 5                                     opened_after_closed  1859  Athina
# 14                            competition_start_after_end  1906  Athina
#
#    Country      Opened      Closed Comments                         Game_Type  \
# 4      GRE  1906-04-22  1906-05-02     <NA>                Intercalated Games
# 6      GRE        None        None     <NA>  Forerunners to the Olympic Games
# 7      GRE  1875-05-11  1875-05-18     <NA>  Forerunners to the Olympic Games
# 5      GRE        None        None     <NA>  Forerunners to the Olympic Games
# 14     GRE  1906-04-22  1906-05-02     <NA>                Intercalated Games
#
#    Competition_Start Competition_End  Game_Id  Opened_Imputed  Closed_Imputed
# 4         1906-04-22      1906-05-02        8           False           False
# 6               None            None        2           False           False
# 7         1875-05-11      1875-05-18        3            True            True
# 5               None            None        1           False           False
# 14        1906-04-22      1906-05-02        8           False           False

# %% [markdown]
# **Results Data Quality Failure Cases:**

# %%
results_failure_cases_df.sample(5)
# Out:
#                    As  Athlete_Id     Discipline  \
# 18         Lu Xiaojun      121984  Weightlifting
# 20        Daniel Böhm      127807       Biathlon
# 0   Albert Pettersson       56746  Weightlifting
# 6    Mickey Patterson       77934      Athletics
# 11   Christoph Sumann      101195       Biathlon
#
#                                       Event        Game Type  Game Year  \
# 18              Middleweight, Men (Olympic)  Summer Olympics       2016
# 20  4 × 7.5 kilometres Relay, Men (Olympic)  Winter Olympics       2014
# 0               Middleweight, Men (Olympic)  Summer Olympics       1920
# 6               200 metres, Women (Olympic)  Summer Olympics       1948
# 11  4 × 7.5 kilometres Relay, Men (Olympic)  Winter Olympics       2014
#
#      Medal  NOC  Position   Tied             failed_check     Team
# 18  Silver  CHN         1  False  Position–Medal mismatch     <NA>
# 20  Silver  GER         1  False  Position–Medal mismatch  Germany
# 0   Bronze  SWE         2   True  Position–Medal mismatch     <NA>
# 6   Bronze  USA         4  False  Position–Medal mismatch     <NA>
# 11  Bronze  AUT         2  False  Position–Medal mismatch  Austria

# %% [markdown]
# # Final Cleaned Warehouse Model

# %%
dim_athletes_df=pd.read_parquet(f"s3://{gold_bucket}/clean_data_final/dim_athletes.parquet", storage_options=s3fs_opts)
dim_affiliations_df=pd.read_parquet(f"s3://{gold_bucket}/clean_data_final/dim_affiliations.parquet", storage_options=s3fs_opts)
bridge_athletes_affiliations_df=pd.read_parquet(f"s3://{gold_bucket}/clean_data_final/bridge_athletes_affiliations.parquet", storage_options=s3fs_opts)
dim_games_df=pd.read_parquet(f"s3://{gold_bucket}/clean_data_final/dim_games.parquet", storage_options=s3fs_opts)
fct_results_df=pd.read_parquet(f"s3://{gold_bucket}/clean_data_final/fct_results.parquet", storage_options=s3fs_opts)

# %% [markdown]
# **Athletes Dimension Table:**

# %%
dim_athletes_df.sample(5)
# Out:
#         athlete_id       athlete_name              athlete_roles athlete_sex  \
# 81519        82192        Tina Riegel  Competed in Olympic Games      Female
# 126756      129088       Lea Yanitsas  Competed in Olympic Games      Female
# 4425          4451        Ray Cillien  Competed in Olympic Games        Male
# 12760        12831  Sandro Chikhladze  Competed in Olympic Games        Male
# 20079        20222      Armand Schlée  Competed in Olympic Games        Male
#
#          athlete_NOC  athlete_height_cm  athlete_weight_kg athlete_born_date  \
# 81519        germany              150.0               38.0        1965-08-25
# 126756     australia              173.0               77.0        1989-03-15
# 4425      luxembourg              181.0               81.0        1939-06-26
# 12760   unified team              168.0               65.0        1965-06-20
# 20079    switzerland              177.0               73.0        1911-01-01
#
#        athlete_died_date  athlete_is_alive   athlete_born_city  \
# 81519                NaT              True           Stuttgart
# 126756               NaT              True          Paddington
# 4425          1991-09-22             False    Esch-sur-Alzette
# 12760                NaT              True                <NA>
# 20079                NaT              True  Castagnola, Lugano
#
#        athlete_born_region athlete_born_country  athlete_is_height_imputed  \
# 81519   Baden-Württemberg                   GER                      False
# 126756    New South Wales                   AUS                      False
# 4425           Luxembourg                   LUX                      False
# 12760                 <NA>                 None                      False
# 20079              Ticino                   SUI                       True
#
#         athlete_is_weight_imputed  athlete_is_born_country_from_NOC
# 81519                       False                             False
# 126756                      False                             False
# 4425                        False                             False
# 12760                       False                              True
# 20079                        True                             False

# %% [markdown]
# **Affiliations Dimension Table:**

# %%
dim_affiliations_df.sample(5)
# Out:
#        affiliation_id      dim_affiliation_club dim_affiliation_city  \
# 32686           32686         Western Athletics                 None
# 3472             3472         Reitclub Burgdorf                 None
# 37291           37291                    Kloten                 None
# 15551           15551       Grenoble Union Club                 None
# 29245           29245  Notts Gymnastics Academy           Nottingham
#
#       dim_affiliation_country
# 32686                    None
# 3472                     None
# 37291                    None
# 15551                    None
# 29245                     GBR

# %% [markdown]
# **Athletes-Affiliations Bridge Table:**

# %%
bridge_athletes_affiliations_df.sample(5)
# Out:
#        athlete_id  affiliation_id
# 16253       15536               0
# 77291       73881           16927
# 93156       88816           20529
# 66571       63863           14383
# 82206       78459           11913

# %% [markdown]
# **Games Dimension Table:**

# %%
dim_games_df.sample(5)
# Out:
#     game_id                     dim_game_type dim_edition_name dim_game_year  \
# 58       59               Youth Olympic Games           Summer          2010
# 26       27                     Olympic Games           Summer          1952
# 3         4  Forerunners to the Olympic Games                           1889
# 31       32                     Olympic Games           Summer          1960
# 5         6                     Olympic Games           Summer          1900
#
#      dim_city dim_country  dim_opened  dim_closed dim_competition_start  \
# 58  Singapore         SGP  2010-08-14  2010-08-26            2010-08-12
# 26   Helsinki         FIN  1952-07-19  1952-08-03            1952-07-14
# 3      Athina         GRE  1889-12-01  1889-04-30            1889-12-01
# 31       Roma         ITA  1960-08-25  1960-09-11            1960-08-25
# 5       Paris         FRA  1900-05-14  1900-10-28            1900-05-14
#
#    dim_competition_end dim_comments  dim_opened_imputed  dim_closed_imputed
# 58          2010-08-26         <NA>               False               False
# 26          1952-08-03         <NA>               False               False
# 3           1889-04-30         <NA>                True                True
# 31          1960-09-11         <NA>               False               False
# 5           1900-10-28         <NA>                True                True

# %% [markdown]
# **Results Fact Table:**

# %%
fct_results_df.sample(5)
# Out:
#         athlete_id dim_noc                    dim_discipline    dim_game_type  \
# 106883       48647     JPN               Swimming (Aquatics)  Summer Olympics
# 68014        30886     POL  Artistic Gymnastics (Gymnastics)  Summer Olympics
# 164311       78586     USA                         Athletics  Summer Olympics
# 11565         7288     BEL           Basketball (Basketball)  Summer Olympics
# 10647         6605     YUG           Basketball (Basketball)  Summer Olympics
#
#         dim_game_year                                     dim_event_name  \
# 106883           1988              100 metres Butterfly, Women (Olympic)
# 68014            1968                      Floor Exercise, Men (Olympic)
# 164311           1904  Discus Throw, Handicap, Men (Olympic (non-medal))
# 11565            1936                          Basketball, Men (Olympic)
# 10647            1972                          Basketball, Men (Olympic)
#
#        dim_team_name             dim_as  m_tied_flag  m_position m_medal
# 106883          <NA>      Takayo Kitano        False          14    <NA>
# 68014           <NA>  Aleksander Rokosa         True          51    <NA>
# 164311          <NA>        Will Hunter        False           2    <NA>
# 11565        Belgium  Gustave Vereecken         True          19    <NA>
# 10647     Yugoslavia      Milun Marović        False           5    <NA>
